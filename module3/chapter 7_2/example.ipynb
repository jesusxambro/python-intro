# %%
basic_tuple = (1,2,3)
print(basic_tuple)
# Out:
# (1, 2, 3)

# %%
import matplotlib

# %%
# for items in massive_list:
#     #add to x list

# %%
import matplotlib.pyplot as plt

x = [0, 1, 2, 3, 4]
y = [0, 1, 4, 9, 16]

plt.plot(x,y)

plt.title("Simple Line Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

plt.show()

# %%
x_coords = [0, 1, 2, 3, 4]
y_coords = [0, 3, 1, 5, 2]
plt.plot(x_coords, y_coords)

plt.show()
